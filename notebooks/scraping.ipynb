# %%
import requests
from bs4 import BeautifulSoup
import time 
import random
import pandas as pd

# %%
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}
URL_BASE = 'https://cosmetics.specialchem.com'
links = []

# %%
for i in range(1,158):
    print(f'scraping page {i}')
    url = f'https://cosmetics.specialchem.com/selectors?indexpage={i}'
    r = requests.get(url, headers=header)
    print(r.status_code)
    soup = BeautifulSoup(r.content, "html.parser")
    items = soup.find_all("div", class_="box_product")
    for item in items:
        val = item.find('a',href=True)
        links.append(URL_BASE+val['href'])
len(links)
# Out:
# scraping page 1
# 200
# scraping page 2
# 200
# scraping page 3
# 200
# scraping page 4
# 200
# scraping page 5
# 200
# scraping page 6
# 200
# scraping page 7
# 200
# scraping page 8
# 200
# scraping page 9
# 200
# scraping page 10
# 200
# scraping page 11
# 200
# scraping page 12
# 200
# scraping page 13
# 200
# scraping page 14
# 200
# scraping page 15
# 200
# scraping page 16
# 200
# scraping page 17
# 200
# scraping page 18
# 200
# scraping page 19
# 200
# scraping page 20
# 200
# scraping page 21
# 200
# scraping page 22
# 200
# scraping page 23
# 200
# scraping page 24
# 200
# scraping page 25
# 200
# scraping page 26
# 200
# scraping page 27
# 200
# scraping page 28
# 200
# scraping page 29
# 200
# scraping page 30
# 200
# scraping page 31
# 200
# scraping page 32
# 200
# scraping page 33
# 200
# scraping page 34
# 200
# scraping page 35
# 200
# scraping page 36
# 200
# scraping page 37
# 200
# scraping page 38
# 200
# scraping page 39
# 200
# scraping page 40
# 200
# scraping page 41
# 200
# scraping page 42
# 200
# scraping page 43
# 200
# scraping page 44
# 200
# scraping page 45
# 200
# scraping page 46
# 200
# scraping page 47
# 200
# scraping page 48
# 200
# scraping page 49
# 200
# scraping page 50
# 200
# scraping page 51
# 200
# scraping page 52
# 200
# scraping page 53
# 200
# scraping page 54
# 200
# scraping page 55
# 200
# scraping page 56
# 200
# scraping page 57
# 200
# scraping page 58
# 200
# scraping page 59
# 200
# scraping page 60
# 200
# scraping page 61
# 200
# scraping page 62
# 200
# scraping page 63
# 200
# scraping page 64
# 200
# scraping page 65
# 200
# scraping page 66
# 200
# scraping page 67
# 200
# scraping page 68
# 200
# scraping page 69
# 200
# scraping page 70
# 200
# scraping page 71
# 200
# scraping page 72
# 200
# scraping page 73
# 200
# scraping page 74
# 200
# scraping page 75
# 200
# scraping page 76
# 200
# scraping page 77
# 200
# scraping page 78
# 200
# scraping page 79
# 200
# scraping page 80
# 200
# scraping page 81
# 200
# scraping page 82
# 200
# scraping page 83
# 200
# scraping page 84
# 200
# scraping page 85
# 200
# scraping page 86
# 200
# scraping page 87
# 200
# scraping page 88
# 200
# scraping page 89
# 200
# scraping page 90
# 200
# scraping page 91
# 200
# scraping page 92
# 200
# scraping page 93
# 200
# scraping page 94
# 200
# scraping page 95
# 200
# scraping page 96
# 200
# scraping page 97
# 200
# scraping page 98
# 200
# scraping page 99
# 200
# scraping page 100
# 200
# scraping page 101
# 200
# scraping page 102
# 200
# scraping page 103
# 200
# scraping page 104
# 200
# scraping page 105
# 200
# scraping page 106
# 200
# scraping page 107
# 200
# scraping page 108
# 200
# scraping page 109
# 200
# scraping page 110
# 200
# scraping page 111
# 200
# scraping page 112
# 200
# scraping page 113
# 200
# scraping page 114
# 200
# scraping page 115
# 200
# scraping page 116
# 200
# scraping page 117
# 200
# scraping page 118
# 200
# scraping page 119
# 200
# scraping page 120
# 200
# scraping page 121
# 200
# scraping page 122
# 200
# scraping page 123
# 200
# scraping page 124
# 200
# scraping page 125
# 200
# scraping page 126
# 200
# scraping page 127
# 200
# scraping page 128
# 200
# scraping page 129
# 200
# scraping page 130
# 200
# scraping page 131
# 200
# scraping page 132
# 200
# scraping page 133
# 200
# scraping page 134
# 200
# scraping page 135
# 200
# scraping page 136
# 200
# scraping page 137
# 200
# scraping page 138
# 200
# scraping page 139
# 200
# scraping page 140
# 200
# scraping page 141
# 200
# scraping page 142
# 200
# scraping page 143
# 200
# scraping page 144
# 200
# scraping page 145
# 200
# scraping page 146
# 200
# scraping page 147
# 200
# scraping page 148
# 200
# scraping page 149
# 200
# scraping page 150
# 200
# scraping page 151
# 200
# scraping page 152
# 200
# scraping page 153
# 200
# scraping page 154
# 200
# scraping page 155
# 200
# scraping page 156
# 200
# scraping page 157
# 200
# 10460

# %%
#guardar en csv links para scrapear descripcion
pd.DataFrame(links).to_csv('links_to_scrape.csv')

# %% [markdown]
# - loop por las 158 paginas
#   - - jalar links y a cada link apendearle al inicio la URL BASE
#
# - entrar a cada link y extraer parrafo

# %%
#intentar sacar parrafo
url2 = 'https://cosmetics.specialchem.com/product/i-adeka-majime-bio-kiwi'
r2 = requests.get(url2, headers=header)
print(r.status_code)
soup = BeautifulSoup(r2.content, "html.parser")
item = soup.find("div", class_="box_comments box_limitable limited")
item.text
# Out:
# 200

# %%
descriptions = []

# %%
random.randint(2,5)
# Out:
# 2

# %%
descriptions=[]

# %%
for i in range(len(links)):
    print(f'scraping element {i}')
    r2 = requests.get(links[i],headers=header)
    print(r2.status_code)
    soup = BeautifulSoup(r2.content,'html.parser')
    item = soup.find("div", class_="box_comments box_limitable limited")
    descriptions.append(item.text)
    if i %20 == 0:
        print('sleeping 10 seconds')
        time.sleep(20)
# Out:
# scraping element 0
# 200
# sleeping 10 seconds
# scraping element 1
# 200
# scraping element 2
# 200
# scraping element 3
# 200
# scraping element 4
# 200
# scraping element 5
# 200
# scraping element 6
# 200
# scraping element 7
# 200
# scraping element 8
# 200
# scraping element 9
# 200
# scraping element 10
# 200
# scraping element 11
# 200
# scraping element 12
# 200
# scraping element 13
# 200
# scraping element 14
# 200
# scraping element 15
# 200
# scraping element 16
# 200
# scraping element 17
# 200
# scraping element 18
# 200
# scraping element 19
# 200
# scraping element 20
# 200
# sleeping 10 seconds
# scraping element 21
# 429
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ml/dhg91nmd1bs970g0q3ypf5l40000gn/T/ipykernel_63472/3300421687.py in <module>
#       5     soup = BeautifulSoup(r2.content,'html.parser')
#       6     item = soup.find("div", class_="box_comments box_limitable limited")
# ----> 7     descriptions.append(item.text)
#       8     if i %20 == 0:
#       9         print('sleeping 10 seconds')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# links[20]

r2 = requests.get(links[21],headers=header)
soup = BeautifulSoup(r2.content,'html.parser')
item = soup.find("div", class_="box_comments box_limitable limited")
item.text
# Out:
# '\nC13-15 Alkane (and) Disteardimonium Hectorite (and) Polyglyceryl-3 Polyricinoleate. BENTONE® LUXE XO by Elementis is a non-animal, non-abrasive, cold processable emulsifying gel and rheological additive for silicone free, water in oil systems with extremely high oil content. It boosts SPF & water resistance and exhibits excellent wear resistance & superior film formation. It provides predictable, reproducible & stable viscosity control, shear-thinning viscosity, excellent suspension of pigments & actives and controlled alignment of special-effect pigments. It offers emulsion stabilization [w/o] and thermostable viscosity which elevates apparent melting point & ensures cost-efficient use of UV filters. It imparts high degree of formulating flexibility as well as unique, luxurious, velvety, smooth, silky and non-greasy feel to the skin. BENTONE® LUXE XO is used in color cosmetics, lip care, eye make-up, facial make-up, emulsions, hand hydrating creams, lotions and water in silicone emulsions, sun protection and after-sun products. It is Vegan, China conforming and RSPO approved. It has a shelf life of 2 years.\nRead More View less\n'
